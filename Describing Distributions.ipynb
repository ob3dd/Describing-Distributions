# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
plt.style.use(['seaborn-muted','fivethirtyeight'])
sns.set_context('talk')
# Out:
# /var/folders/j7/rq_q1cb16yx0w__bmvd7lzx80000gn/T/ipykernel_20293/245686344.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use(['seaborn-muted','fivethirtyeight'])

# %%
df = pd.read_csv("Medical Dataset/data (3).csv")
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %% [markdown]
# ## VitD_levels

# %%
# plotting the KDE diagram
sns.histplot(data=df, x='VitD_levels', discrete=True, stat='density', kde = True);

# %% [markdown]
# ### Mean

# %%
# Find the mean
mean = df['VitD_levels'].mean()
mean
# Out:
# 17.992380894860002

# %%
# Adding a line to the mean
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(df['VitD_levels'], ax = ax, stat='probability')
ax.axvline(mean, color = 'red', linestyle='--');
ax.set_title('VitD_levels');

# %% [markdown]
# ### Median

# %%
# Find the median
median = df['VitD_levels'].median()
median
# Out:
# 18.020163095

# %%
# Adding a line to the median
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### STD

# %%
# Add a line for for +1 std from the mean
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
std = feature.std()
plus_one_std = mean + std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black', linestyle='--', label=f'+1 std = {plus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
# Add a line for for -1 std from the mean
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
std = feature.std()
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(minus_one_std, color = 'black', linestyle='--', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### Highlight

# %%
# Highlight the range between +1 and =1 std
col = 'VitD_levels'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow')
ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['VitD_levels'], fisher = False)

# %% [markdown]
# ## Doc_visits

# %%
# plotting the KDE diagram
sns.histplot(data=df, x='Doc_visits', discrete=True, stat='density', kde = True);

# %% [markdown]
# ### Mean

# %%
# Find the mean
mean = df['Doc_visits'].mean()
mean
# Out:
# 4.992

# %%
# Adding a line to the mean
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(df['Doc_visits'], ax = ax, stat='probability')
ax.axvline(mean, color = 'red', linestyle='--');
ax.set_title('Doc_visits');

# %% [markdown]
# ### Median

# %%
# Find the median
median = df['Doc_visits'].median()
median
# Out:
# 5.0

# %%
# Adding a line to the median
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### STD

# %%
# Add a line for for +1 std from the mean
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
std = feature.std()
plus_one_std = mean + std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black', linestyle='--', label=f'+1 std = {plus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
# Add a line for for -1 std from the mean
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
std = feature.std()
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(minus_one_std, color = 'black', linestyle='--', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### Highlight

# %%
# Highlight the range between +1 and =1 std
col = 'Doc_visits'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow')
ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['Doc_visits'], fisher = False)

# %% [markdown]
# ## TotalCharge

# %%
# plotting the KDE diagram
sns.histplot(data=df, x='TotalCharge', discrete=True, stat='density', kde = True);

# %% [markdown]
# ### Mean

# %%
# Find the mean
mean = df['TotalCharge'].mean()
mean
# Out:
# 3240.9716133389998

# %%
# Adding a line to the mean
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(df['TotalCharge'], ax = ax, stat='probability')
ax.axvline(mean, color = 'red', linestyle='--');
ax.set_title('TotalCharge');

# %% [markdown]
# ### Median

# %%
# Find the median
median = df['TotalCharge'].median()
median
# Out:
# 3164.6792455

# %%
# Adding a line to the median
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(mean, color = 'red',label=f'Mean = {mean:,.2f}')
ax.axvline(median, ls='--', color = 'green', label = f'Median = {median:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### STD

# %%
# Add a line for for +1 std from the mean
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
std = feature.std()
plus_one_std = mean + std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black', linestyle='--', label=f'+1 std = {plus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %%
# Add a line for for -1 std from the mean
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
std = feature.std()
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(10,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(minus_one_std, color = 'black', linestyle='--', label = f'-1 std = {minus_one_std:,.2f}')
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# ### Highlight

# %%
# Highlight the range between +1 and =1 std
col = 'TotalCharge'
feature = df[col]
mean = feature.mean()
median = feature.median()
std = feature.std()
plus_one_std = mean + std
minus_one_std = mean - std
fig,ax = plt.subplots(figsize=(9,4))
sns.histplot(feature ,ax=ax,stat='probability')
ax.axvline(plus_one_std, color = 'black',label=f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow')
ax.set_title(f'{col}')
ax.legend();

# %%
from scipy import stats
kurt = stats.kurtosis(df['TotalCharge'], fisher = False)

# %% [markdown]
# ## Part 2

# %% [markdown]
# ### VitD_levels

# %% [markdown]
# Is it Discrete or Continuous?
#
# **ANS**: It is a discrete value
#
# Does it have a skew? If so, which direction (+/-)
#
# **ANS**: No skew
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# **ANS**: Leptokurtic - Positive Kurtosis

# %% [markdown]
# ### Doc_visits

# %% [markdown]
# Is it Discrete or Continuous?
#
# **ANS**: It is a discrete value
#
# Does it have a skew? If so, which direction (+/-)
#
# **ANS**: No skew
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# **ANS**: Leptokurtic - Positive Kurtosis

# %% [markdown]
# ### TotalCharge

# %% [markdown]
# Is it Discrete or Continuous?
#
# **ANS**: It is a discrete value
#
# Does it have a skew? If so, which direction (+/-)
#
# **ANS**: Positive skew
#
# What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
# **ANS**: Platykurtic - Negative Kurtosis
